# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content')
# !tar xpf /content/drive/MyDrive/images.tgz
# !mv '/content/images' '/content/images_12-3-21'

# %%
os.chdir('/content/images_12-3-21')
os.rename('negative', '0')
os.rename('people', '1')
os.rename('stopsign', '2')

# %%
# remove stop signs
#!rm -rf '/content/images_12-3-21/2' 
# remove people
# !rm -rf '/content/images_12-3-21/1'
# !mv '/content/images_12-3-21/2' '/content/images_12-3-21/1'

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model
from tensorflow.keras.applications import imagenet_utils
from sklearn.metrics import confusion_matrix
import itertools
import os
import shutil
import random
import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# Organize data into train, valid, test dirs
os.chdir('/content/images_12-3-21')
if os.path.isdir('train/0/') is False: 
  os.mkdir('train')
  os.mkdir('valid')

  for i in range(0, 2):
    shutil.move(f'{i}', 'train')
    os.mkdir(f'valid/{i}')

    valid_samples = random.sample(os.listdir(f'train/{i}'), 30)
    for j in valid_samples:
      shutil.move(f'train/{i}/{j}', f'valid/{i}')

train_path = '/content/images_12-3-21/train'
valid_path = '/content/images_12-3-21/valid'

train_batches = ImageDataGenerator(preprocessing_function=tf.keras.applications.mobilenet.preprocess_input).flow_from_directory(directory=train_path, target_size=(224,224), batch_size=10)
valid_batches = ImageDataGenerator(preprocessing_function=tf.keras.applications.mobilenet.preprocess_input).flow_from_directory(directory=valid_path, target_size=(224,224), batch_size=10)

mobile = tf.keras.applications.mobilenet.MobileNet()

#x = mobile.layers[-6].output
x = mobile.output

output = Dense(units=2, activation='softmax')(x)

model = Model(inputs=mobile.input, outputs=output)

#for layer in model.layers[:-23]:
#    layer.trainable = False

model.compile(optimizer=Adam(lr=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])
model.fit(x=train_batches,
            steps_per_epoch=len(train_batches),
            validation_data=valid_batches,
            validation_steps=len(valid_batches),
            epochs=80,
            verbose=2
)
# Out:
# Found 4010 images belonging to 2 classes.
# Found 60 images belonging to 2 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf.h5
# 17227776/17225924 [==============================] - 0s 0us/step
# 17235968/17225924 [==============================] - 0s 0us/step
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/80
# 401/401 - 67s - loss: 0.6158 - accuracy: 0.9803 - val_loss: 0.5998 - val_accuracy: 1.0000 - 67s/epoch - 167ms/step
# Epoch 2/80
# 401/401 - 47s - loss: 0.5644 - accuracy: 0.9933 - val_loss: 0.5528 - val_accuracy: 1.0000 - 47s/epoch - 118ms/step
# Epoch 3/80
# 401/401 - 48s - loss: 0.5211 - accuracy: 0.9955 - val_loss: 0.5171 - val_accuracy: 1.0000 - 48s/epoch - 119ms/step
# Epoch 4/80
# 401/401 - 47s - loss: 0.4793 - accuracy: 0.9950 - val_loss: 0.4826 - val_accuracy: 1.0000 - 47s/epoch - 116ms/step
# Epoch 5/80
# 401/401 - 46s - loss: 0.4424 - accuracy: 0.9973 - val_loss: 0.4543 - val_accuracy: 1.0000 - 46s/epoch - 115ms/step
# Epoch 6/80
# 401/401 - 45s - loss: 0.4127 - accuracy: 0.9978 - val_loss: 0.4293 - val_accuracy: 1.0000 - 45s/epoch - 113ms/step
# Epoch 7/80
# 401/401 - 46s - loss: 0.3869 - accuracy: 0.9975 - val_loss: 0.4065 - val_accuracy: 1.0000 - 46s/epoch - 116ms/step
# Epoch 8/80
# 401/401 - 46s - loss: 0.3634 - accuracy: 0.9985 - val_loss: 0.3853 - val_accuracy: 1.0000 - 46s/epoch - 114ms/step
# Epoch 9/80
# 401/401 - 45s - loss: 0.3434 - accuracy: 0.9963 - val_loss: 0.3654 - val_accuracy: 1.0000 - 45s/epoch - 113ms/step
# Epoch 10/80
# 401/401 - 45s - loss: 0.3221 - accuracy: 0.9988 - val_loss: 0.3464 - val_accuracy: 1.0000 - 45s/epoch - 113ms/step
# Epoch 11/80
# 401/401 - 46s - loss: 0.3040 - accuracy: 0.9988 - val_loss: 0.3282 - val_accuracy: 1.0000 - 46s/epoch - 115ms/step
# Epoch 12/80
# 401/401 - 46s - loss: 0.2862 - accuracy: 0.9993 - val_loss: 0.3109 - val_accuracy: 1.0000 - 46s/epoch - 115ms/step
# Epoch 13/80
# 401/401 - 45s - loss: 0.2704 - accuracy: 0.9990 - val_loss: 0.2944 - val_accuracy: 1.0000 - 45s/epoch - 113ms/step
# Epoch 14/80
# 401/401 - 45s - loss: 0.2553 - accuracy: 0.9990 - val_loss: 0.2786 - val_accuracy: 1.0000 - 45s/epoch - 113ms/step
# Epoch 15/80
# 401/401 - 46s - loss: 0.2410 - accuracy: 0.9990 - val_loss: 0.2635 - val_accuracy: 1.0000 - 46s/epoch - 116ms/step
# Epoch 16/80
# 401/401 - 46s - loss: 0.2273 - accuracy: 0.9993 - val_loss: 0.2490 - val_accuracy: 1.0000 - 46s/epoch - 115ms/step
# Epoch 17/80
# 401/401 - 45s - loss: 0.2145 - accuracy: 0.9993 - val_loss: 0.2353 - val_accuracy: 1.0000 - 45s/epoch - 113ms/step
# Epoch 18/80
# 401/401 - 45s - loss: 0.2024 - accuracy: 0.9993 - val_loss: 0.2221 - val_accuracy: 1.0000 - 45s/epoch - 113ms/step
# Epoch 19/80
# 401/401 - 46s - loss: 0.1910 - accuracy: 0.9993 - val_loss: 0.2096 - val_accuracy: 1.0000 - 46s/epoch - 115ms/step
# Epoch 20/80
# 401/401 - 46s - loss: 0.2183 - accuracy: 0.9788 - val_loss: 1.1243 - val_accuracy: 0.5000 - 46s/epoch - 115ms/step
# Epoch 21/80
# 401/401 - 45s - loss: 0.4449 - accuracy: 0.6648 - val_loss: 0.5367 - val_accuracy: 0.5000 - 45s/epoch - 113ms/step
# Epoch 22/80
# 401/401 - 45s - loss: 0.3869 - accuracy: 0.6651 - val_loss: 0.4833 - val_accuracy: 0.5000 - 45s/epoch - 113ms/step
# Epoch 23/80
# 401/401 - 47s - loss: 0.1684 - accuracy: 0.9923 - val_loss: 0.1850 - val_accuracy: 0.9833 - 47s/epoch - 116ms/step
# Epoch 24/80
# 401/401 - 46s - loss: 0.1525 - accuracy: 0.9988 - val_loss: 0.1657 - val_accuracy: 1.0000 - 46s/epoch - 115ms/step
# Epoch 25/80
# 401/401 - 45s - loss: 0.1417 - accuracy: 0.9995 - val_loss: 0.1551 - val_accuracy: 1.0000 - 45s/epoch - 113ms/step
# Epoch 26/80
# 401/401 - 45s - loss: 0.1348 - accuracy: 0.9983 - val_loss: 0.1415 - val_accuracy: 1.0000 - 45s/epoch - 113ms/step
# Epoch 27/80
# 401/401 - 46s - loss: 0.1258 - accuracy: 0.9990 - val_loss: 0.1685 - val_accuracy: 0.9833 - 46s/epoch - 116ms/step
# Epoch 28/80
# 401/401 - 46s - loss: 0.1180 - accuracy: 0.9993 - val_loss: 0.1637 - val_accuracy: 0.9833 - 46s/epoch - 115ms/step
# Epoch 29/80
# 401/401 - 45s - loss: 0.1113 - accuracy: 0.9993 - val_loss: 0.1265 - val_accuracy: 1.0000 - 45s/epoch - 113ms/step
# Epoch 30/80
# 401/401 - 46s - loss: 0.1042 - accuracy: 0.9995 - val_loss: 0.1528 - val_accuracy: 0.9833 - 46s/epoch - 114ms/step
# Epoch 31/80
# 401/401 - 47s - loss: 0.0980 - accuracy: 0.9995 - val_loss: 0.1476 - val_accuracy: 0.9833 - 47s/epoch - 116ms/step
# Epoch 32/80
# 401/401 - 46s - loss: 0.0988 - accuracy: 0.9963 - val_loss: 0.0995 - val_accuracy: 1.0000 - 46s/epoch - 115ms/step
# Epoch 33/80
# 401/401 - 45s - loss: 0.0898 - accuracy: 0.9980 - val_loss: 0.0938 - val_accuracy: 1.0000 - 45s/epoch - 112ms/step
# Epoch 34/80
# 401/401 - 45s - loss: 0.0826 - accuracy: 0.9993 - val_loss: 0.0885 - val_accuracy: 1.0000 - 45s/epoch - 113ms/step
# Epoch 35/80
# 401/401 - 46s - loss: 0.0779 - accuracy: 0.9993 - val_loss: 0.0833 - val_accuracy: 1.0000 - 46s/epoch - 115ms/step
# Epoch 36/80
# 401/401 - 46s - loss: 0.0735 - accuracy: 0.9993 - val_loss: 0.0915 - val_accuracy: 0.9833 - 46s/epoch - 115ms/step
# Epoch 37/80
# 401/401 - 45s - loss: 0.0690 - accuracy: 0.9993 - val_loss: 0.0867 - val_accuracy: 0.9833 - 45s/epoch - 112ms/step
# Epoch 38/80
# 401/401 - 45s - loss: 0.0649 - accuracy: 0.9993 - val_loss: 0.0696 - val_accuracy: 1.0000 - 45s/epoch - 113ms/step
# Epoch 39/80
# 401/401 - 46s - loss: 0.0610 - accuracy: 0.9995 - val_loss: 0.0655 - val_accuracy: 1.0000 - 46s/epoch - 116ms/step
# Epoch 40/80
# 401/401 - 46s - loss: 0.0574 - accuracy: 0.9995 - val_loss: 0.0616 - val_accuracy: 1.0000 - 46s/epoch - 115ms/step
# Epoch 41/80
# 401/401 - 45s - loss: 0.0549 - accuracy: 0.9993 - val_loss: 0.0580 - val_accuracy: 1.0000 - 45s/epoch - 113ms/step
# Epoch 42/80
# 401/401 - 45s - loss: 0.0511 - accuracy: 0.9995 - val_loss: 0.0546 - val_accuracy: 1.0000 - 45s/epoch - 113ms/step
# Epoch 43/80
# 401/401 - 46s - loss: 0.0481 - accuracy: 0.9995 - val_loss: 0.0514 - val_accuracy: 1.0000 - 46s/epoch - 116ms/step
# Epoch 44/80
# 401/401 - 46s - loss: 0.0454 - accuracy: 0.9995 - val_loss: 0.0484 - val_accuracy: 1.0000 - 46s/epoch - 115ms/step
# Epoch 45/80
# 401/401 - 45s - loss: 0.0428 - accuracy: 0.9995 - val_loss: 0.0455 - val_accuracy: 1.0000 - 45s/epoch - 113ms/step
# Epoch 46/80
# 401/401 - 45s - loss: 0.0404 - accuracy: 0.9995 - val_loss: 0.0429 - val_accuracy: 1.0000 - 45s/epoch - 113ms/step
# Epoch 47/80
# 401/401 - 46s - loss: 0.0381 - accuracy: 0.9995 - val_loss: 0.0403 - val_accuracy: 1.0000 - 46s/epoch - 115ms/step
# Epoch 48/80
# 401/401 - 46s - loss: 0.0360 - accuracy: 0.9995 - val_loss: 0.0380 - val_accuracy: 1.0000 - 46s/epoch - 115ms/step
# Epoch 49/80
# 401/401 - 45s - loss: 0.0340 - accuracy: 0.9995 - val_loss: 0.0358 - val_accuracy: 1.0000 - 45s/epoch - 112ms/step
# Epoch 50/80
# 401/401 - 45s - loss: 0.0321 - accuracy: 0.9995 - val_loss: 0.0337 - val_accuracy: 1.0000 - 45s/epoch - 113ms/step
# Epoch 51/80
# 401/401 - 46s - loss: 0.0303 - accuracy: 0.9995 - val_loss: 0.0317 - val_accuracy: 1.0000 - 46s/epoch - 115ms/step
# Epoch 52/80
# 401/401 - 46s - loss: 0.0287 - accuracy: 0.9995 - val_loss: 0.0299 - val_accuracy: 1.0000 - 46s/epoch - 115ms/step
# Epoch 53/80
# 401/401 - 45s - loss: 0.0271 - accuracy: 0.9995 - val_loss: 0.0282 - val_accuracy: 1.0000 - 45s/epoch - 112ms/step
# Epoch 54/80
# 401/401 - 45s - loss: 0.0257 - accuracy: 0.9995 - val_loss: 0.0266 - val_accuracy: 1.0000 - 45s/epoch - 113ms/step
# Epoch 55/80
# 401/401 - 46s - loss: 0.0243 - accuracy: 0.9995 - val_loss: 0.0250 - val_accuracy: 1.0000 - 46s/epoch - 115ms/step
# Epoch 56/80
# 401/401 - 46s - loss: 0.0230 - accuracy: 0.9995 - val_loss: 0.0236 - val_accuracy: 1.0000 - 46s/epoch - 114ms/step
# Epoch 57/80
# 401/401 - 45s - loss: 0.0218 - accuracy: 0.9995 - val_loss: 0.0223 - val_accuracy: 1.0000 - 45s/epoch - 113ms/step
# Epoch 58/80
# 401/401 - 45s - loss: 0.0207 - accuracy: 0.9995 - val_loss: 0.0210 - val_accuracy: 1.0000 - 45s/epoch - 113ms/step
# Epoch 59/80
# 401/401 - 46s - loss: 0.0294 - accuracy: 0.9965 - val_loss: 0.0202 - val_accuracy: 1.0000 - 46s/epoch - 116ms/step
# Epoch 60/80
# 401/401 - 46s - loss: 0.0190 - accuracy: 0.9995 - val_loss: 0.0192 - val_accuracy: 1.0000 - 46s/epoch - 115ms/step
# Epoch 61/80
# 401/401 - 45s - loss: 0.0204 - accuracy: 0.9990 - val_loss: 0.0183 - val_accuracy: 1.0000 - 45s/epoch - 113ms/step
# Epoch 62/80
# 401/401 - 46s - loss: 0.0195 - accuracy: 0.9985 - val_loss: 0.0180 - val_accuracy: 1.0000 - 46s/epoch - 114ms/step
# Epoch 63/80
# 401/401 - 46s - loss: 0.0171 - accuracy: 0.9993 - val_loss: 0.0166 - val_accuracy: 1.0000 - 46s/epoch - 115ms/step
# Epoch 64/80
# 401/401 - 46s - loss: 0.0159 - accuracy: 0.9995 - val_loss: 0.0158 - val_accuracy: 1.0000 - 46s/epoch - 115ms/step
# Epoch 65/80
# 401/401 - 45s - loss: 0.0152 - accuracy: 0.9995 - val_loss: 0.0150 - val_accuracy: 1.0000 - 45s/epoch - 113ms/step
# Epoch 66/80
# 401/401 - 45s - loss: 0.0146 - accuracy: 0.9995 - val_loss: 0.0142 - val_accuracy: 1.0000 - 45s/epoch - 113ms/step
# Epoch 67/80
# 401/401 - 46s - loss: 0.0139 - accuracy: 0.9995 - val_loss: 0.0135 - val_accuracy: 1.0000 - 46s/epoch - 116ms/step
# Epoch 68/80
# 401/401 - 46s - loss: 0.0134 - accuracy: 0.9995 - val_loss: 0.0128 - val_accuracy: 1.0000 - 46s/epoch - 115ms/step
# Epoch 69/80
# 401/401 - 45s - loss: 0.0135 - accuracy: 0.9990 - val_loss: 0.0138 - val_accuracy: 1.0000 - 45s/epoch - 112ms/step
# Epoch 70/80
# 401/401 - 45s - loss: 0.0124 - accuracy: 0.9995 - val_loss: 0.0512 - val_accuracy: 0.9833 - 45s/epoch - 113ms/step
# Epoch 71/80
# 401/401 - 47s - loss: 0.0131 - accuracy: 0.9993 - val_loss: 0.0110 - val_accuracy: 1.0000 - 47s/epoch - 116ms/step
# Epoch 72/80
# 401/401 - 46s - loss: 0.0115 - accuracy: 0.9995 - val_loss: 0.0105 - val_accuracy: 1.0000 - 46s/epoch - 115ms/step
# Epoch 73/80
# 401/401 - 45s - loss: 0.0109 - accuracy: 0.9995 - val_loss: 0.0100 - val_accuracy: 1.0000 - 45s/epoch - 113ms/step
# Epoch 74/80
# 401/401 - 45s - loss: 0.0105 - accuracy: 0.9995 - val_loss: 0.0095 - val_accuracy: 1.0000 - 45s/epoch - 113ms/step
# Epoch 75/80
# 401/401 - 47s - loss: 0.0101 - accuracy: 0.9995 - val_loss: 0.0091 - val_accuracy: 1.0000 - 47s/epoch - 116ms/step
# Epoch 76/80
# 401/401 - 46s - loss: 0.0097 - accuracy: 0.9995 - val_loss: 0.0087 - val_accuracy: 1.0000 - 46s/epoch - 115ms/step
# Epoch 77/80
# 401/401 - 45s - loss: 0.0094 - accuracy: 0.9995 - val_loss: 0.0083 - val_accuracy: 1.0000 - 45s/epoch - 112ms/step
# Epoch 78/80
# 401/401 - 45s - loss: 0.0091 - accuracy: 0.9995 - val_loss: 0.0079 - val_accuracy: 1.0000 - 45s/epoch - 113ms/step
# Epoch 79/80
# 401/401 - 46s - loss: 0.0088 - accuracy: 0.9995 - val_loss: 0.0076 - val_accuracy: 1.0000 - 46s/epoch - 116ms/step
# Epoch 80/80
# 401/401 - 46s - loss: 0.0085 - accuracy: 0.9995 - val_loss: 0.0073 - val_accuracy: 1.0000 - 46s/epoch - 115ms/step

# %%
model.save('/content/stop_dec_mobilenet', save_format='tf')
# Converting a SavedModel to a TensorFlow Lite model.
converter = tf.lite.TFLiteConverter.from_saved_model('/content/stop_dec_mobilenet')
tflite_model = converter.convert()
open("/content/stop_dec_mobilenet.tflite", "wb").write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: /content/stop_dec_mobilenet/assets
# WARNING:absl:Buffer deduplication procedure will be skipped when flatbuffer library is not properly loaded
# 16909432

# %%
# !mv /content/stop_dec_mobilenet.tflite /content/drive/MyDrive/stop_mobilenet4_full.tflite
